# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("Documents\Loan_Prediction1.csv")

# %%
df
# Out:
#     Gender Married Dependents     Education  ApplicantIncome  \
# 0     Male     Yes          0      Graduate             5720
# 1     Male     Yes          1      Graduate             3076
# 2     Male     Yes          2      Graduate             5000
# 3     Male     Yes          2      Graduate             2340
# 4     Male      No          0  Not Graduate             3276
# ..     ...     ...        ...           ...              ...
# 362   Male     Yes         3+  Not Graduate             4009
# 363   Male     Yes          0      Graduate             4158
# 364   Male      No          0      Graduate             3250
# 365   Male     Yes          0      Graduate             5000
# 366   Male      No          0      Graduate             9200
#
#      CoapplicantIncome  Loan Amt
# 0                    0     360.0
# 1                 1500     360.0
# 2                 1800     360.0
# 3                 2546     360.0
# 4                    0     360.0
# ...

# %%
df.head(n=5)
# Out:
#   Gender Married Dependents     Education  ApplicantIncome  CoapplicantIncome  \
# 0   Male     Yes          0      Graduate             5720                  0
# 1   Male     Yes          1      Graduate             3076               1500
# 2   Male     Yes          2      Graduate             5000               1800
# 3   Male     Yes          2      Graduate             2340               2546
# 4   Male      No          0  Not Graduate             3276                  0
#
#    Loan Amt
# 0     360.0
# 1     360.0
# 2     360.0
# 3     360.0
# 4     360.0

# %%
df.tail(n=6)
# Out:
#     Gender Married Dependents     Education  ApplicantIncome  \
# 361   Male     Yes          1      Graduate             2269
# 362   Male     Yes         3+  Not Graduate             4009
# 363   Male     Yes          0      Graduate             4158
# 364   Male      No          0      Graduate             3250
# 365   Male     Yes          0      Graduate             5000
# 366   Male      No          0      Graduate             9200
#
#      CoapplicantIncome  Loan Amt
# 361               2167     360.0
# 362               1777     360.0
# 363                709     360.0
# 364               1993     360.0
# 365               2393     360.0
# 366                  0     180.0

# %%
df.index
# Out:
# RangeIndex(start=0, stop=367, step=1)

# %%
df.shape
# Out:
# (367, 7)

# %%
df.dtypes
# Out:
# Gender                object
# Married               object
# Dependents            object
# Education             object
# ApplicantIncome        int64
# CoapplicantIncome      int64
# Loan Amt             float64
# dtype: object

# %%
df.columns.values
# Out:
# array(['Gender', 'Married', 'Dependents', 'Education', 'ApplicantIncome',
#        'CoapplicantIncome', 'Loan Amt'], dtype=object)

# %%
df.describe(include='all')
# Out:
#        Gender Married Dependents Education  ApplicantIncome  \
# count     356     367        357       367       367.000000
# unique      2       2          4         2              NaN
# top      Male     Yes          0  Graduate              NaN
# freq      286     233        200       283              NaN
# mean      NaN     NaN        NaN       NaN      4805.599455
# std       NaN     NaN        NaN       NaN      4910.685399
# min       NaN     NaN        NaN       NaN         0.000000
# 25%       NaN     NaN        NaN       NaN      2864.000000
# 50%       NaN     NaN        NaN       NaN      3786.000000
# 75%       NaN     NaN        NaN       NaN      5060.000000
# max       NaN     NaN        NaN       NaN     72529.000000
#
#         CoapplicantIncome    Loan Amt
# count          367.000000  361.000000
# unique                NaN         NaN
# top                   NaN         NaN
# freq                  NaN         NaN
# mean          1569.577657  342.537396
# ...

# %%
df['Dependents']
# Out:
# 0       0
# 1       1
# 2       2
# 3       2
# 4       0
#        ..
# 362    3+
# 363     0
# 364     0
# 365     0
# 366     0
# Name: Dependents, Length: 367, dtype: object

# %%
df.isnull()
# Out:
#      Gender  Married  Dependents  Education  ApplicantIncome  \
# 0     False    False       False      False            False
# 1     False    False       False      False            False
# 2     False    False       False      False            False
# 3     False    False       False      False            False
# 4     False    False       False      False            False
# ..      ...      ...         ...        ...              ...
# 362   False    False       False      False            False
# 363   False    False       False      False            False
# 364   False    False       False      False            False
# 365   False    False       False      False            False
# 366   False    False       False      False            False
#
#      CoapplicantIncome  Loan Amt
# 0                False     False
# 1                False     False
# 2                False     False
# 3                False     False
# 4                False     False
# ...

# %%
df.isnull().any()
# Out:
# Gender                True
# Married              False
# Dependents            True
# Education            False
# ApplicantIncome      False
# CoapplicantIncome    False
# Loan Amt              True
# dtype: bool

# %%
df.isnull().sum().sum()
# Out:
# 27

# %%
df.isnull().sum(axis=1)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 362    0
# 363    0
# 364    0
# 365    0
# 366    0
# Length: 367, dtype: int64

# %%
df.isnull().sum()
# Out:
# Gender               11
# Married               0
# Dependents           10
# Education             0
# ApplicantIncome       0
# CoapplicantIncome     0
# Loan Amt              6
# dtype: int64

# %%
df.Dependents.isnull().sum()
# Out:
# 10

# %%
df.groupby(['Gender'])['Loan Amt'].apply(lambda x:x.isnull().sum())
# Out:
# Gender
# Female    0
# Male      6
# Name: Loan Amt, dtype: int64

# %%
from sklearn import preprocessing
df.head()
# Out:
#   Gender Married Dependents     Education  ApplicantIncome  CoapplicantIncome  \
# 0   Male     Yes          0      Graduate             5720                  0
# 1   Male     Yes          1      Graduate             3076               1500
# 2   Male     Yes          2      Graduate             5000               1800
# 3   Male     Yes          2      Graduate             2340               2546
# 4   Male      No          0  Not Graduate             3276                  0
#
#    Loan Amt
# 0     360.0
# 1     360.0
# 2     360.0
# 3     360.0
# 4     360.0

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
label_encoder = preprocessing.LabelEncoder()
df['Gender']=label_encoder.fit_transform(df['Gender'])
df['Gender'].unique()
# Out:
# array([1, 0, 2])

# %%
one_hot_df = pd.get_dummies(df, prefix='Gender',columns=['Gender'],drop_first=True)
one_hot_df
# Out:
#     Married Dependents     Education  ApplicantIncome  CoapplicantIncome  \
# 0       Yes          0      Graduate             5720                  0
# 1       Yes          1      Graduate             3076               1500
# 2       Yes          2      Graduate             5000               1800
# 3       Yes          2      Graduate             2340               2546
# 4        No          0  Not Graduate             3276                  0
# ..      ...        ...           ...              ...                ...
# 362     Yes         3+  Not Graduate             4009               1777
# 363     Yes          0      Graduate             4158                709
# 364      No          0      Graduate             3250               1993
# 365     Yes          0      Graduate             5000               2393
# 366      No          0      Graduate             9200                  0
#
#      Loan Amt  Gender_1  Gender_2
# 0       360.0      True     False
# ...

# %%
df.sort_index(axis=1,ascending=False)
# Out:
#     Married  Loan Amt  Gender     Education Dependents  CoapplicantIncome  \
# 0       Yes     360.0       1      Graduate          0                  0
# 1       Yes     360.0       1      Graduate          1               1500
# 2       Yes     360.0       1      Graduate          2               1800
# 3       Yes     360.0       1      Graduate          2               2546
# 4        No     360.0       1  Not Graduate          0                  0
# ..      ...       ...     ...           ...        ...                ...
# 362     Yes     360.0       1  Not Graduate         3+               1777
# 363     Yes     360.0       1      Graduate          0                709
# 364      No     360.0       1      Graduate          0               1993
# 365     Yes     360.0       1      Graduate          0               2393
# 366      No     180.0       1      Graduate          0                  0
#
#      ApplicantIncome
# 0               5720
# 1               3076
# ...

# %%
df.iloc[5]
# Out:
# Gender                          1
# Married                       Yes
# Dependents                      0
# Education            Not Graduate
# ApplicantIncome              2165
# CoapplicantIncome            3422
# Loan Amt                    360.0
# Name: 5, dtype: object

# %%
df[0:3]
# Out:
#    Gender Married Dependents Education  ApplicantIncome  CoapplicantIncome  \
# 0       1     Yes          0  Graduate             5720                  0
# 1       1     Yes          1  Graduate             3076               1500
# 2       1     Yes          2  Graduate             5000               1800
#
#    Loan Amt
# 0     360.0
# 1     360.0
# 2     360.0

# %%
df.loc[:,["Married","Loan Amt"]]
# Out:
#     Married  Loan Amt
# 0       Yes     360.0
# 1       Yes     360.0
# 2       Yes     360.0
# 3       Yes     360.0
# 4        No     360.0
# ..      ...       ...
# 362     Yes     360.0
# 363     Yes     360.0
# 364      No     360.0
# 365     Yes     360.0
# 366      No     180.0
#
# [367 rows x 2 columns]

# %%
df.iloc[3:5,0:2]
# Out:
#    Gender Married
# 3       1     Yes
# 4       1      No

# %%
df.drop(['Married'],axis=1)
# Out:
#      Gender Dependents     Education  ApplicantIncome  CoapplicantIncome  \
# 0         1          0      Graduate             5720                  0
# 1         1          1      Graduate             3076               1500
# 2         1          2      Graduate             5000               1800
# 3         1          2      Graduate             2340               2546
# 4         1          0  Not Graduate             3276                  0
# ..      ...        ...           ...              ...                ...
# 362       1         3+  Not Graduate             4009               1777
# 363       1          0      Graduate             4158                709
# 364       1          0      Graduate             3250               1993
# 365       1          0      Graduate             5000               2393
# 366       1          0      Graduate             9200                  0
#
#      Loan Amt
# 0       360.0
# 1       360.0
# 2       360.0
# 3       360.0
# ...

# %%
df.head()
# Out:
#    Gender Married Dependents     Education  ApplicantIncome  \
# 0       1     Yes          0      Graduate             5720
# 1       1     Yes          1      Graduate             3076
# 2       1     Yes          2      Graduate             5000
# 3       1     Yes          2      Graduate             2340
# 4       1      No          0  Not Graduate             3276
#
#    CoapplicantIncome  Loan Amt
# 0                  0     360.0
# 1               1500     360.0
# 2               1800     360.0
# 3               2546     360.0
# 4                  0     360.0
