# %%
Name : Tavhare Siddhi Santosh
Roll No : 59
Practical No : 04

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Downloads/housing.csv")

# %%
df.head(5)
# Out:
#       RM  LSTAT  PTRATIO      MEDV
# 0  6.575   4.98     15.3  504000.0
# 1  6.421   9.14     17.8  453600.0
# 2  7.185   4.03     17.8  728700.0
# 3  6.998   2.94     18.7  701400.0
# 4  7.147   5.33     18.7  760200.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 489 entries, 0 to 488
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   RM       489 non-null    float64
#  1   LSTAT    489 non-null    float64
#  2   PTRATIO  489 non-null    float64
#  3   MEDV     489 non-null    float64
# dtypes: float64(4)
# memory usage: 15.4 KB

# %%
miss_value=df.isnull().sum()
print("No of missing value in each feature")
print(miss_value)
# Out:
# No of missing value in each feature
# RM         0
# LSTAT      0
# PTRATIO    0
# MEDV       0
# dtype: int64

# %%
df=df.fillna(df.mean())
print("Dataframe with missing values replaced by mean")
df.head()
# Out:
# Dataframe with missing values replaced by mean
#       RM  LSTAT  PTRATIO      MEDV
# 0  6.575   4.98     15.3  504000.0
# 1  6.421   9.14     17.8  453600.0
# 2  7.185   4.03     17.8  728700.0
# 3  6.998   2.94     18.7  701400.0
# 4  7.147   5.33     18.7  760200.0

# %%
miss_value=df.isnull().sum()
print("No of missing value in each feature")
print(miss_value)
# Out:
# No of missing value in each feature
# RM         0
# LSTAT      0
# PTRATIO    0
# MEDV       0
# dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['MEDV'],bins=30,kde=True,color='blue')
plt.title('Distribution of median Home Values(MEDV)')
plt.xlabel('MEDV(in $1000$)')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\Satyam\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
selected_features = ['RM','LSTAT','PTRATIO','MEDV']
X = df[selected_features]
Y = df['MEDV']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X_train , X_test , Y_train , Y_test = train_test_split(X , Y , test_size=0.2 , random_state=42 )

# %%
print("shape of X_train :",X_train.shape)
print("shape of X_test :",X_test.shape)
print("shape of Y_train :",Y_train.shape)
print("shape of Y_test :",Y_test.shape)
# Out:
# shape of X_train : (391, 4)
# shape of X_test : (98, 4)
# shape of Y_train : (391,)
# shape of Y_test : (98,)

# %%
linear_model = LinearRegression()
linear_model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
l_pred=linear_model.predict(X_test)

# %%
from sklearn.metrics import r2_score
mse = r2_score(Y_test,l_pred)
print("Total Mean Sqaured Error = ",mse)
# Out:
# Total Mean Sqaured Error =  1.0

# %%
plt.figure(figsize=(10,6))
plt.scatter(Y_test,l_pred,color='green',alpha=0.6)
plt.title("Linear Regression : Actual Vs Predicted")
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.grid(True)
plt.show()
