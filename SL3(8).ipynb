# %%
Name : Tavhare Siddhi Santosh
Roll No : 59
Practical No : 08

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv('Income Status.csv')

# %%
df
# Out:
#     Customer ID  Age  Annual Income  Spending Score  Gender
# 0         10108   23          15000              10    Male
# 1         10109   21          20000              15    Male
# 2        101010   24          25000              34    Male
# 3        101011   25          27500              25  Female
# 4        101012   23          45000              45    Male
# 5        101013   26          23000              38  Female
# 6        101014   28          43600              67  Female
# 7        111015   30          21567              45    Male
# 8        111016   23          45367              78    Male
# 9        111017   25          45789              34  Female
# 10       111018   28          23000              56  Female
# 11       111019   29          21000              78  Female
# 12       111020   31          47000              90    Male
# 13       111021   27          23650              34    Male

# %%
#Distribution Plot
sns.distplot(x = df['Age'], bins = 10)
# Out:
# <Axes: ylabel='Density'>

# %%
#Distribution Plot
sns.distplot(df['Age'], bins = 10,kde=False)
# Out:
# <Axes: xlabel='Age'>

# %%
#Joint Plot
sns.jointplot(x = df['Age'], y = df['Spending Score'], kind = 'scatter')

# %%
#Rug Plot
sns.rugplot(data=df, x ="Annual Income")
# Out:
# <Axes: xlabel='Annual Income'>

# %%
#Bar Plot
sns.barplot(x='Gender', y='Age', data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %%
sns.barplot(x='Spending Score', y='Age', data=df, estimator=np.std)
# Out:
# <Axes: xlabel='Spending Score', ylabel='Age'>

# %%
#Count Plot
sns.countplot(x='Gender', data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
#Box Plot
sns.boxplot(x='Gender', y='Age', data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %%
sns.boxplot(x='Gender', y='Age', data=df, hue="Spending Score")
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %%
#Violin Plot
sns.violinplot(x='Gender', y='Age', data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %%
sns.violinplot(x='Gender', y='Age', data=df, hue='Spending Score')
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %%
#Strip Plot
sns.stripplot(x='Gender', y='Age', data=df, jitter=False)
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %%
sns.stripplot(x='Gender', y='Age', data=df, jitter=True)
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %%
sns.stripplot(x='Gender', y='Age', data=df, jitter=True, hue='Spending Score')
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %%
#swarm Plot
sns.swarmplot(x='Gender', y='Age', data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %%
sns.swarmplot(x='Gender', y='Age', data=df, hue='Annual Income')
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %%
data=pd.read_csv('Loan_Prediction1.csv')

# %%
data.head()
# Out:
#   Gender Married Dependents     Education  ApplicantIncome  CoapplicantIncome  \
# 0   Male     Yes          0      Graduate             5720                  0
# 1   Male     Yes          1      Graduate             3076               1500
# 2   Male     Yes          2      Graduate             5000               1800
# 3   Male     Yes          2      Graduate             2340               2546
# 4   Male      No          0  Not Graduate             3276                  0
#
#    Loan Amt
# 0     360.0
# 1     360.0
# 2     360.0
# 3     360.0
# 4     360.0

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['Gender'] = le.fit_transform(data['Gender'])

# %%
newdf=data

# %%
data
# Out:
#      Gender Married Dependents     Education  ApplicantIncome  \
# 0         1     Yes          0      Graduate             5720
# 1         1     Yes          1      Graduate             3076
# 2         1     Yes          2      Graduate             5000
# 3         1     Yes          2      Graduate             2340
# 4         1      No          0  Not Graduate             3276
# ..      ...     ...        ...           ...              ...
# 362       1     Yes         3+  Not Graduate             4009
# 363       1     Yes          0      Graduate             4158
# 364       1      No          0      Graduate             3250
# 365       1     Yes          0      Graduate             5000
# 366       1      No          0      Graduate             9200
#
#      CoapplicantIncome  Loan Amt
# 0                    0     360.0
# 1                 1500     360.0
# 2                 1800     360.0
# 3                 2546     360.0
# 4                    0     360.0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['Married'] = le.fit_transform(data['Married'])
newdf=data

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['Dependents'] = le.fit_transform(data['Dependents'])
newdf=data

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['Education'] = le.fit_transform(data['Education'])
newdf=data

# %%
corr = data.corr() 
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
corr = data.corr()
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %%
sns.histplot(data['ApplicantIncome'], kde=False, bins=10)
# Out:
# <Axes: xlabel='ApplicantIncome', ylabel='Count'>
